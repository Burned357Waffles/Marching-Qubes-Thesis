# %% [markdown]
# # Marching Qubes Classical V1
# ## Brandon Watanabe
#
# This will be a python implementation of the Custodio et al. algorithm "Practical considerations on Marching Cubes 33 topological correctness"
# <br>
# https://www.sci.utah.edu/~etiene/pdf/mc33.pdf
#
# Source code can be found here:
# https://liscustodio.github.io/C_MC33/index.html

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# EOF
